# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Kathryn Small__ <br>
# Currently a postdoc in Material Science

# %% [markdown]
# _Data science is interesting to me because I enjoy finding patterns and solving problems. I'm interested in using data to solve transportation issues and inform city infrastructure to reduce car dependence._

# %% [markdown]
# ### In cell 5 I print "Hello world" and plot a circle using matplotlib

# %%
import matplotlib.pyplot as plt

print("Hello world")

figure, axes = plt.subplots()
draw_circle = plt.Circle((.5, .5), .4)
axes.set_aspect(1)
axes.add_artist(draw_circle)
plt.show()
# Out:
# Hello world

# %% [markdown]
#
#
# Today is the 20th anniversary of <a href="https://en.wikipedia.org/wiki/Firefly_(TV_series)">Firefly (TV Series)</a>, a show about:
#
# - space pirates with a wild west vibe
# - dystopian government agency
# - living on the edge of society
# - mysterious brain surgery leading to psychic powers... sort of
# ***
#
# ![firefly.png](attachment:ecfcb0c7-d1fe-472d-abd5-676c36e9433c.png)
